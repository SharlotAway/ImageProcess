# %%
import argparse
import glob
import h5py
import numpy as np
import PIL.Image as pil_image
from torchvision.transforms import transforms

# %%
# !CUDA_VISIBLE_DEVICES=3 python models.py
# Out:
# ...
# Evaluating: 100%|████████████████████████████| 100/100 [00:00<00:00, 205.75it/s]
# Epoch [1/200]:
# Train Loss: 0.1013
# Valid Loss: 0.0665, PSNR: 11.99dB
# Saved best model to checkpoints/best_tcn.pth
# ...
# Evaluating: 100%|████████████████████████████| 100/100 [00:00<00:00, 251.97it/s]
# Epoch [2/200]:
# Train Loss: 0.0501
# Valid Loss: 0.0320, PSNR: 15.10dB
# Saved best model to checkpoints/best_tcn.pth
# ...
# Evaluating: 100%|████████████████████████████| 100/100 [00:00<00:00, 258.99it/s]
# Epoch [3/200]:
# Train Loss: 0.0345
# Valid Loss: 0.0183, PSNR: 17.66dB
# Saved best model to checkpoints/best_tcn.pth
# ...
# Evaluating: 100%|████████████████████████████| 100/100 [00:00<00:00, 250.17it/s]
# Epoch [4/200]:
# Train Loss: 0.0228
# Valid Loss: 0.0131, PSNR: 19.17dB
# Saved best model to checkpoints/best_tcn.pth
# ...
# Evaluating: 100%|████████████████████████████| 100/100 [00:00<00:00, 254.79it/s]
# Epoch [5/200]:
# Train Loss: 0.0164
# Valid Loss: 0.0084, PSNR: 21.25dB
# ...
